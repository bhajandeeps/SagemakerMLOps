# %% [markdown]
# # Reading the necessary libs and setting the stage

# %%
# creation of data sources using 
import boto3
import json

client  = boto3.client('quicksight')
quicksight  = boto3.client('quicksight')
account_id = '854807003520'
ds_id = '24e6bcd0-932e-4a9a-8b8d-bdf43ac09935'

# ________________________________list data source______________________________________________
list_datasource = quicksight.list_data_sources(AwsAccountId= account_id)
list_datasource
# Out:
# {'ResponseMetadata': {'RequestId': 'ad9c912c-b74e-4aa9-8802-cbaa5b12619c',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:46 GMT',
#    'content-type': 'application/json',
#    'content-length': '112602',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'ad9c912c-b74e-4aa9-8802-cbaa5b12619c'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'DataSources': [{'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/09d007b6-40b9-4a6b-9ecf-00b4294378f1',
#    'DataSourceId': '09d007b6-40b9-4a6b-9ecf-00b4294378f1',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 22, 11, 20, 981000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 22, 11, 20, 981000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/15136bc7-4898-4396-8042-05713fdd807b',
#    'DataSourceId': '15136bc7-4898-4396-8042-05713fdd807b',
#    'Name': 'testing',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 59, 7, 642000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 59, 7, 642000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/160233ac-73ac-4d38-bb8b-e17e1ee02d5e',
#    'DataSourceId': '160233ac-73ac-4d38-bb8b-e17e1ee02d5e',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 13, 8, 54, 443000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 13, 8, 54, 443000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/16ca31f2-4356-42d3-b76f-9b0123da76d1',
#    'DataSourceId': '16ca31f2-4356-42d3-b76f-9b0123da76d1',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 13, 3, 51, 315000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 13, 3, 51, 315000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/39c2b958-3e3e-4638-845e-12db4f2f4be4',
#    'DataSourceId': '39c2b958-3e3e-4638-845e-12db4f2f4be4',
#    'Name': 'ds_mlops_database',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 23, 1, 22, 10, 16000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 23, 1, 22, 10, 16000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/3ea5c4b4-6e19-4d34-825d-92bbbbd36c4c',
#    'DataSourceId': '3ea5c4b4-6e19-4d34-825d-92bbbbd36c4c',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 15, 5, 39, 39000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 15, 5, 39, 39000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/516c132e-382a-4d5b-a715-47615c7cf963',
#    'DataSourceId': '516c132e-382a-4d5b-a715-47615c7cf963',
#    'Name': 'brand_lkp_data_restricted',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 30, 48, 317000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 30, 48, 317000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/55d5c9da-884d-47b8-8e5a-df42175d537a',
#    'DataSourceId': '55d5c9da-884d-47b8-8e5a-df42175d537a',
#    'Name': 'testings',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 20, 41, 45, 428000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 20, 41, 45, 428000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/5dc6e7fc-3fdd-4e55-a600-4caee89bc30e',
#    'DataSourceId': '5dc6e7fc-3fdd-4e55-a600-4caee89bc30e',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 29, 17, 38, 16, 768000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 29, 17, 38, 16, 768000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/6132d625-25cf-402b-a5e4-91afb775e773',
#    'DataSourceId': '6132d625-25cf-402b-a5e4-91afb775e773',
#    'Name': 'TestDevOps',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 10, 19, 21, 56, 965000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 10, 19, 21, 56, 965000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/66048b11-1cc9-4716-ae3a-bfaa0c04a87d',
#    'DataSourceId': '66048b11-1cc9-4716-ae3a-bfaa0c04a87d',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 13, 3, 26, 932000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 13, 3, 26, 932000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/6956706c-5832-4566-9888-ecc1adf92190',
#    'DataSourceId': '6956706c-5832-4566-9888-ecc1adf92190',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 29, 17, 35, 2, 987000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 29, 17, 35, 2, 987000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/6a326235-0481-46b6-8428-bc042563a250',
#    'DataSourceId': '6a326235-0481-46b6-8428-bc042563a250',
#    'Name': 'tt',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 6, 18, 33, 7, 735000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 6, 18, 33, 7, 735000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/6e697346-82ab-4c18-9394-49d1374d11fc',
#    'DataSourceId': '6e697346-82ab-4c18-9394-49d1374d11fc',
#    'Name': 'Test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 17, 24, 21, 554000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 17, 24, 21, 554000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/7cf597b3-9eda-4605-8ede-e7ae3dbaf02a',
#    'DataSourceId': '7cf597b3-9eda-4605-8ede-e7ae3dbaf02a',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 22, 4, 37, 437000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 22, 4, 37, 437000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/95fa2984-969e-4e07-b129-007ae1837691',
#    'DataSourceId': '95fa2984-969e-4e07-b129-007ae1837691',
#    'Name': 't',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 19, 4, 23, 671000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 19, 4, 23, 671000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/a4c0f016-a8aa-42f6-8fd4-19572a6008ca',
#    'DataSourceId': 'a4c0f016-a8aa-42f6-8fd4-19572a6008ca',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 12, 58, 46, 513000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 12, 58, 46, 513000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/0780e86b-c89d-46ac-8a0c-d9238968af6c',
#    'DataSourceId': '0780e86b-c89d-46ac-8a0c-d9238968af6c',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 42, 43, 611000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 42, 43, 611000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/099e239b-0bb6-46d0-b460-cb040e2840a6',
#    'DataSourceId': '099e239b-0bb6-46d0-b460-cb040e2840a6',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 18, 26, 12, 478000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 18, 26, 12, 478000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/0d7bf76b-4c12-428c-9759-6e92644a30c2',
#    'DataSourceId': '0d7bf76b-4c12-428c-9759-6e92644a30c2',
#    'Name': 'ModelDataDriftDB',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 46, 14, 747000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 46, 14, 747000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/1ae5f9bc-abe8-475c-9265-cd02d9015cba',
#    'DataSourceId': '1ae5f9bc-abe8-475c-9265-cd02d9015cba',
#    'Name': 'DataDrift_Mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 4, 4, 52, 323000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 4, 4, 52, 323000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/1c4e5927-533a-4e45-b4f1-212cfa4edc5d',
#    'DataSourceId': '1c4e5927-533a-4e45-b4f1-212cfa4edc5d',
#    'Name': 'ModelDataDriftDB',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 14, 26, 754000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 14, 26, 754000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/202f5b25-8946-4ebd-b3cb-87fd2908164a',
#    'DataSourceId': '202f5b25-8946-4ebd-b3cb-87fd2908164a',
#    'Name': 'Scoring Analysis',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 20, 38, 388000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 20, 38, 388000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/24e6bcd0-932e-4a9a-8b8d-bdf43ac09935',
#    'DataSourceId': '24e6bcd0-932e-4a9a-8b8d-bdf43ac09935',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 39, 13, 601000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 39, 13, 601000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/24e6bcd0-932e-4a9a-8b9d-bdf43ac09935',
#    'DataSourceId': '24e6bcd0-932e-4a9a-8b9d-bdf43ac09935',
#    'Name': 'Scoring_MLOPs',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 2, 15, 7, 41, 816000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 2, 15, 7, 52, 656000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/24e6bcd0-932e-4a9a-8b9d-bdf43bc09935',
#    'DataSourceId': '24e6bcd0-932e-4a9a-8b9d-bdf43bc09935',
#    'Name': 'DataDrift_MLOPs',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 3, 1, 39, 51, 465000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 3, 1, 39, 52, 806000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/2c9de630-e3aa-4336-850d-86f9643b9c0f',
#    'DataSourceId': '2c9de630-e3aa-4336-850d-86f9643b9c0f',
#    'Name': 'datadift_analysis',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 3, 28, 40, 112000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 3, 28, 40, 112000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/2de2fda5-781b-4159-81d3-d5ab0f821130',
#    'DataSourceId': '2de2fda5-781b-4159-81d3-d5ab0f821130',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 12, 33, 34, 112000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 12, 33, 34, 112000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/3c30ee69-4bc6-45a1-9dac-37769deec503',
#    'DataSourceId': '3c30ee69-4bc6-45a1-9dac-37769deec503',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 19, 1, 5, 16, 397000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 19, 1, 5, 16, 397000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/42ba1802-ca97-434a-9ae7-dbfe9bb1aac4',
#    'DataSourceId': '42ba1802-ca97-434a-9ae7-dbfe9bb1aac4',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 25, 19, 107000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 25, 19, 107000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/44f04c1a-af9b-44a6-9417-7ab4f67fb640',
#    'DataSourceId': '44f04c1a-af9b-44a6-9417-7ab4f67fb640',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 12, 47, 28, 993000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 12, 47, 28, 993000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/4847c388-271b-4e16-84ee-176cac01c4bb',
#    'DataSourceId': '4847c388-271b-4e16-84ee-176cac01c4bb',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 31, 2, 51, 8, 561000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 31, 2, 51, 8, 561000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/57138d7f-c4f3-4525-8f49-b1015af94fe1',
#    'DataSourceId': '57138d7f-c4f3-4525-8f49-b1015af94fe1',
#    'Name': 'ds-mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 16, 49, 699000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 16, 49, 699000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/5ba562fd-f533-4579-9ac0-b2d0fa4b20ff',
#    'DataSourceId': '5ba562fd-f533-4579-9ac0-b2d0fa4b20ff',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 15, 11, 43, 922000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 15, 11, 43, 922000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/639ee5eb-e649-4143-8c01-e1c438d7f1c2',
#    'DataSourceId': '639ee5eb-e649-4143-8c01-e1c438d7f1c2',
#    'Name': 'Crp',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 29, 19, 48000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 29, 19, 48000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/63aa357c-fd33-4ebe-b071-312bc3803c5b',
#    'DataSourceId': '63aa357c-fd33-4ebe-b071-312bc3803c5b',
#    'Name': 'dsmlops_datadrift_analysis',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 26, 14, 53, 24, 666000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 26, 14, 53, 24, 666000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/6c199d47-c831-4330-8fb5-e05aef02a716',
#    'DataSourceId': '6c199d47-c831-4330-8fb5-e05aef02a716',
#    'Name': 'll',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 2, 15, 15, 16, 219000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 2, 15, 15, 16, 219000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/71e9a6ed-1b53-437d-9b84-ca7d807a5eee',
#    'DataSourceId': '71e9a6ed-1b53-437d-9b84-ca7d807a5eee',
#    'Name': 'ds-mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 17, 25, 790000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 17, 25, 790000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/72c6263b-0164-4662-9d11-582bc17cf7ea',
#    'DataSourceId': '72c6263b-0164-4662-9d11-582bc17cf7ea',
#    'Name': 'Test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 15, 10, 0, 107000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 15, 10, 0, 107000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/74aceed9-445c-4fa0-aa4a-f68f8b004a2f',
#    'DataSourceId': '74aceed9-445c-4fa0-aa4a-f68f8b004a2f',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 24, 48, 346000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 24, 48, 346000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/74ff520f-07b7-46b2-bc59-0ad0d05231ff',
#    'DataSourceId': '74ff520f-07b7-46b2-bc59-0ad0d05231ff',
#    'Name': 'datadrift_viz_mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 3, 3, 34, 750000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 3, 3, 34, 750000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/7f0afcfd-44d4-4d16-9c64-898a14692023',
#    'DataSourceId': '7f0afcfd-44d4-4d16-9c64-898a14692023',
#    'Name': 't',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 37, 49, 302000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 37, 49, 302000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/854b6679-a153-486c-807d-314ddf32bf8c',
#    'DataSourceId': '854b6679-a153-486c-807d-314ddf32bf8c',
#    'Name': 'Viz-Mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 17, 19, 46, 977000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 17, 19, 46, 977000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/874db1dd-549f-4349-8b59-ae740ecde7e8',
#    'DataSourceId': '874db1dd-549f-4349-8b59-ae740ecde7e8',
#    'Name': 'Scoring Table',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 15, 24, 77000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 15, 24, 77000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/883a0195-1b74-4299-ae71-46de877fbc7e',
#    'DataSourceId': '883a0195-1b74-4299-ae71-46de877fbc7e',
#    'Name': 'mlops_dev_demo',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 12, 34, 53, 165000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 12, 34, 53, 165000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/88a382f2-1c50-415d-87ac-d76506fc6cac',
#    'DataSourceId': '88a382f2-1c50-415d-87ac-d76506fc6cac',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 12, 24, 58, 231000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 12, 24, 58, 231000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/8ed65621-1747-4b8d-8894-a870b73fd942',
#    'DataSourceId': '8ed65621-1747-4b8d-8894-a870b73fd942',
#    'Name': 'Scoring_trend',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 36, 39, 244000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 36, 39, 244000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/941e3295-5596-490b-a440-5d487863d2de',
#    'DataSourceId': '941e3295-5596-490b-a440-5d487863d2de',
#    'Name': 'ds-mlops',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 17, 42, 577000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 17, 42, 577000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/a21787c6-ad1a-4064-98b4-2470b6ffb5ef',
#    'DataSourceId': 'a21787c6-ad1a-4064-98b4-2470b6ffb5ef',
#    'Name': 'mlops_dev_demo',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 12, 22, 57, 171000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 12, 22, 57, 171000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/a6769994-bd08-4bb2-9b5b-25e053e72fc9',
#    'DataSourceId': 'a6769994-bd08-4bb2-9b5b-25e053e72fc9',
#    'Name': 'Scoring',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 44, 36, 434000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 44, 36, 434000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/a8f782a3-829a-4c22-9d13-7c1e26e3d3a9',
#    'DataSourceId': 'a8f782a3-829a-4c22-9d13-7c1e26e3d3a9',
#    'Name': 'May23',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 5, 12, 53, 482000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 5, 12, 53, 482000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/ac104f79-345b-45f6-ac78-3abe50fd4764',
#    'DataSourceId': 'ac104f79-345b-45f6-ac78-3abe50fd4764',
#    'Name': 'dsmlops_model_monitor',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 25, 10, 51, 12, 949000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 25, 10, 51, 12, 949000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/afa0f016-a526-4630-bee3-f8000018032c',
#    'DataSourceId': 'afa0f016-a526-4630-bee3-f8000018032c',
#    'Name': 't',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 19, 1, 31, 39, 350000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 19, 1, 31, 39, 350000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b1b08439-cb63-4079-91a9-a0cb59a1c3dd',
#    'DataSourceId': 'b1b08439-cb63-4079-91a9-a0cb59a1c3dd',
#    'Name': 'Scoringtrend',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 12, 39, 31, 827000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 12, 39, 31, 827000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b5de41ed-416c-4342-8c83-9d24ce04336f',
#    'DataSourceId': 'b5de41ed-416c-4342-8c83-9d24ce04336f',
#    'Name': 'Tesla',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 28, 47, 253000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 28, 47, 253000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b7fb0466-ede3-4c65-86b5-e0f1c9e59b21',
#    'DataSourceId': 'b7fb0466-ede3-4c65-86b5-e0f1c9e59b21',
#    'Name': 'Basel',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 50, 28, 509000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 50, 28, 509000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/baa4112e-3295-4a96-9d19-75e2c19c88d6',
#    'DataSourceId': 'baa4112e-3295-4a96-9d19-75e2c19c88d6',
#    'Name': 'ModelDataDriftDB',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 13, 35, 4, 685000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 13, 35, 4, 685000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/bd382ba8-56f5-4f20-9985-6bf649fe6741',
#    'DataSourceId': 'bd382ba8-56f5-4f20-9985-6bf649fe6741',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 20, 44, 34, 251000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 20, 44, 34, 251000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/be6d4b3b-fa6c-4de3-99c0-2ce4e631944d',
#    'DataSourceId': 'be6d4b3b-fa6c-4de3-99c0-2ce4e631944d',
#    'Name': 'dsmlops_modelmonitor',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 21, 3, 14, 162000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 21, 3, 14, 162000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/c1343b72-f8c0-4a8d-93bd-7618883e654a',
#    'DataSourceId': 'c1343b72-f8c0-4a8d-93bd-7618883e654a',
#    'Name': 'Dashboard',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 19, 1, 4, 40, 360000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 19, 1, 4, 40, 360000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/c745ae9c-cfd4-475e-a0da-986197bfba2a',
#    'DataSourceId': 'c745ae9c-cfd4-475e-a0da-986197bfba2a',
#    'Name': 'ModelDataDriftDB',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 40, 37, 639000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 40, 37, 639000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/caa742dc-4f41-4702-a85e-6717650faef5',
#    'DataSourceId': 'caa742dc-4f41-4702-a85e-6717650faef5',
#    'Name': 'mlops_demo_dev',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 12, 38, 45, 850000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 12, 38, 45, 850000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/d1668949-f1b8-4d18-a9ef-ef032c4729e7',
#    'DataSourceId': 'd1668949-f1b8-4d18-a9ef-ef032c4729e7',
#    'Name': 'test2',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 5, 14, 11, 303000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 5, 14, 11, 303000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/d470d617-1753-4fc0-b306-fe59d5e2a106',
#    'DataSourceId': 'd470d617-1753-4fc0-b306-fe59d5e2a106',
#    'Name': 'mlops_dev_demo',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 12, 37, 54, 110000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 12, 37, 54, 110000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/da643ef1-2b7e-459c-be3b-e12f2d8f38a9',
#    'DataSourceId': 'da643ef1-2b7e-459c-be3b-e12f2d8f38a9',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 19, 1, 23, 43, 880000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 19, 1, 23, 43, 880000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/ec6a795e-db19-4713-a375-acdef890eefe',
#    'DataSourceId': 'ec6a795e-db19-4713-a375-acdef890eefe',
#    'Name': 'Scoringtrend',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 12, 38, 31, 525000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 12, 38, 31, 525000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/ef12c495-ac15-4d1c-b086-360835bd5dfe',
#    'DataSourceId': 'ef12c495-ac15-4d1c-b086-360835bd5dfe',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 18, 35, 22, 317000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 18, 35, 22, 317000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f3651fbc-20e6-4df0-9cd4-d8dbf549f1f3',
#    'DataSourceId': 'f3651fbc-20e6-4df0-9cd4-d8dbf549f1f3',
#    'Name': 'Best',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 13, 49, 42, 1000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 13, 49, 42, 1000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f7a8a083-5662-440c-a9ea-8c253586413a',
#    'DataSourceId': 'f7a8a083-5662-440c-a9ea-8c253586413a',
#    'Name': 'tesar',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 20, 56, 8, 32000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 20, 56, 8, 32000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b27f0c07-ab37-4b27-8d87-aeda13f26bd6',
#    'DataSourceId': 'b27f0c07-ab37-4b27-8d87-aeda13f26bd6',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 29, 17, 14, 19, 186000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 29, 17, 14, 19, 186000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b49aaa38-4d05-4b20-a364-cafe2f08e80a',
#    'DataSourceId': 'b49aaa38-4d05-4b20-a364-cafe2f08e80a',
#    'Name': 'brand_lkp_data',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 8, 9, 49000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 8, 9, 49000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b716ee9b-90e3-42ce-a484-fdddae458cf7',
#    'DataSourceId': 'b716ee9b-90e3-42ce-a484-fdddae458cf7',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 22, 3, 49, 802000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 22, 3, 49, 802000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b85fa12f-580c-477c-a0c9-5967a2fbec0d',
#    'DataSourceId': 'b85fa12f-580c-477c-a0c9-5967a2fbec0d',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 53, 52, 892000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 53, 52, 892000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/e786e563-6c99-4143-85fd-da264c7fd7f5',
#    'DataSourceId': 'e786e563-6c99-4143-85fd-da264c7fd7f5',
#    'Name': 'testi',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 38, 54, 326000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 38, 54, 326000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/eb7c0054-fd3d-4db4-bc54-a8e792069405',
#    'DataSourceId': 'eb7c0054-fd3d-4db4-bc54-a8e792069405',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 13, 11, 4, 526000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 13, 11, 4, 526000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f47f43df-fc7a-4fe3-aa83-a92082a5901b',
#    'DataSourceId': 'f47f43df-fc7a-4fe3-aa83-a92082a5901b',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 22, 8, 24, 741000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 22, 8, 24, 741000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f6c5ca16-c5b9-45ee-84d4-55e3249eaa0f',
#    'DataSourceId': 'f6c5ca16-c5b9-45ee-84d4-55e3249eaa0f',
#    'Name': 'mlops_model_monitor',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 4, 28, 17, 7, 48, 689000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 4, 28, 17, 7, 48, 689000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f7fead6b-02f4-4a4a-8fa5-66da8ac02b63',
#    'DataSourceId': 'f7fead6b-02f4-4a4a-8fa5-66da8ac02b63',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 17, 16, 8, 247000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 17, 16, 8, 247000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f88fc7d7-25ec-4229-909c-8bcdb7adf5a1',
#    'DataSourceId': 'f88fc7d7-25ec-4229-909c-8bcdb7adf5a1',
#    'Name': 'brand_lkp_data',
#    'Type': 'ATHENA',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 26, 15, 386000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 39, 57, 278000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f8b8b9de-1c3b-49e6-9eb3-ff7fc386ae54',
#    'DataSourceId': 'f8b8b9de-1c3b-49e6-9eb3-ff7fc386ae54',
#    'Name': 'test',
#    'Type': 'ATHENA',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 2, 13, 2, 14, 732000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 2, 13, 2, 14, 732000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#    'SslProperties': {'DisableSsl': False}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/03bf3da7-ab68-4ef3-9e4e-625afe780efa',
#    'DataSourceId': '03bf3da7-ab68-4ef3-9e4e-625afe780efa',
#    'Name': 'Business Review',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 442000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 546000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'revenue/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/1bd16948-c212-4951-a2f9-32c25b1ba9b2',
#    'DataSourceId': '1bd16948-c212-4951-a2f9-32c25b1ba9b2',
#    'Name': 'Web and Social Media Analytics',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 541000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 745000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'marketing/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/260b4032-c0fc-4926-9ecd-bf3e8705459d',
#    'DataSourceId': '260b4032-c0fc-4926-9ecd-bf3e8705459d',
#    'Name': 'Web and Social Media Analytics',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 161000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 281000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'marketing/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/309170fe-310e-4303-a47a-b95a7033d628',
#    'DataSourceId': '309170fe-310e-4303-a47a-b95a7033d628',
#    'Name': 'Sales Pipeline',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 534000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 639000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'sales/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/46f8aa2c-c7e3-4472-8e38-9c11fd119671',
#    'DataSourceId': '46f8aa2c-c7e3-4472-8e38-9c11fd119671',
#    'Name': 'People Overview',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 582000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 672000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'hr/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/4d6f1b7b-c303-4369-b9ea-c82ff340873e',
#    'DataSourceId': '4d6f1b7b-c303-4369-b9ea-c82ff340873e',
#    'Name': 'Business Review',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 579000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 683000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'revenue/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/5b493719-5e39-4f72-8bf1-e9990ab9e1cd',
#    'DataSourceId': '5b493719-5e39-4f72-8bf1-e9990ab9e1cd',
#    'Name': 'People Overview',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 436000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 548000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'hr/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/77d00155-e4b5-447e-bb53-49062e09bb4d',
#    'DataSourceId': '77d00155-e4b5-447e-bb53-49062e09bb4d',
#    'Name': 'Business Review',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 75000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 177000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'revenue/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/7f5c0570-dda8-4357-8365-9505449417c0',
#    'DataSourceId': '7f5c0570-dda8-4357-8365-9505449417c0',
#    'Name': 'People Overview',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 77000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 175000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'hr/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/8275a20f-1cad-4588-a8ea-434725a30d9c',
#    'DataSourceId': '8275a20f-1cad-4588-a8ea-434725a30d9c',
#    'Name': 'Business Review',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 145000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 241000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'revenue/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/8d8120c5-40d5-4582-b732-6703564ed22b',
#    'DataSourceId': '8d8120c5-40d5-4582-b732-6703564ed22b',
#    'Name': 'Web and Social Media Analytics',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 447000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 535000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'marketing/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/93de8986-d25a-446b-a8a3-44052d578210',
#    'DataSourceId': '93de8986-d25a-446b-a8a3-44052d578210',
#    'Name': 'Web and Social Media Analytics',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 578000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 702000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'marketing/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/94d37253-869e-4749-95f5-d46ada2a07cc',
#    'DataSourceId': '94d37253-869e-4749-95f5-d46ada2a07cc',
#    'Name': 'Sales Pipeline',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 582000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 42, 760000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'sales/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/95147975-63da-4444-ae4a-aafddea17bf5',
#    'DataSourceId': '95147975-63da-4444-ae4a-aafddea17bf5',
#    'Name': 'Sales Pipeline',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 71000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 244000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'sales/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/9566b06c-4ab6-4f0d-aafe-8c66fddc7184',
#    'DataSourceId': '9566b06c-4ab6-4f0d-aafe-8c66fddc7184',
#    'Name': 'People Overview',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 537000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 627000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'hr/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/95eb5be2-782f-4773-8340-3f79f24e30a7',
#    'DataSourceId': '95eb5be2-782f-4773-8340-3f79f24e30a7',
#    'Name': 'Sales Pipeline',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 159000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 266000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'sales/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b8755b27-a71a-48c7-9937-1a10010ba640',
#    'DataSourceId': 'b8755b27-a71a-48c7-9937-1a10010ba640',
#    'Name': 'Web and Social Media Analytics',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 69000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 1, 181000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'marketing/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/b8c28704-9b31-4b17-9706-4b8db2f12803',
#    'DataSourceId': 'b8c28704-9b31-4b17-9706-4b8db2f12803',
#    'Name': 'People Overview',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 160000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 39, 301000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'hr/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/e8c40af9-bca5-442b-8da9-45f9e3850d46',
#    'DataSourceId': 'e8c40af9-bca5-442b-8da9-45f9e3850d46',
#    'Name': 'Sales Pipeline',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 450000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 53, 587000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'sales/manifest.json'}}}},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/f63f40d7-57d7-4cac-97fc-6107f199fa19',
#    'DataSourceId': 'f63f40d7-57d7-4cac-97fc-6107f199fa19',
#    'Name': 'Business Review',
#    'Type': 'S3',
#    'Status': 'UPDATE_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 537000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 37, 58, 851000, tzinfo=tzlocal()),
#    'DataSourceParameters': {'S3Parameters': {'ManifestFileLocation': {'Bucket': 'spaceneedle-samplefiles.prod.us-east-1',
#       'Key': 'revenue/manifest.json'}}}}],
#  'NextToken': '...',
#  'RequestId': 'ad9c912c-b74e-4aa9-8802-cbaa5b12619c'}

# %% [markdown]
# # Describing the .JSON for QuickSight

# %%
# _________________________________describe data source_________________________________________
describe_data_source = quicksight.describe_data_source(AwsAccountId=account_id,DataSourceId=ds_id)
describe_data_source
# Out:
# {'ResponseMetadata': {'RequestId': 'e874286a-eb59-464b-87a5-05fefe49d576',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:47 GMT',
#    'content-type': 'application/json',
#    'content-length': '1160',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'e874286a-eb59-464b-87a5-05fefe49d576'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'DataSource': {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/24e6bcd0-932e-4a9a-8b8d-bdf43ac09935',
#   'DataSourceId': '24e6bcd0-932e-4a9a-8b8d-bdf43ac09935',
#   'Name': 'Scoring',
#   'Type': 'ATHENA',
#   'Status': 'CREATION_SUCCESSFUL',
#   'CreatedTime': datetime.datetime(2022, 5, 27, 5, 39, 13, 601000, tzinfo=tzlocal()),
#   'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 39, 13, 601000, tzinfo=tzlocal()),
#   'DataSourceParameters': {'AthenaParameters': {'WorkGroup': 'primary'}},
#   'SslProperties': {'DisableSsl': False}},
#  'RequestId': 'e874286a-eb59-464b-87a5-05fefe49d576'}

# %%
with open ("scoring_data_source.json", "w") as outfile:
    json.dump(describe_data_source, outfile, indent=4, sort_keys=True, default=str) # dictionary to json

# %% [markdown]
# # Describing the Dataset For QuickSight

# %%
#_____________________________________ Extracting variables from Json______________________________________

ds_Id = describe_data_source['DataSource']['DataSourceId']
ds_Name = describe_data_source['DataSource']['Name']
ds_parameters = describe_data_source['DataSource']['DataSourceParameters']
ssl = describe_data_source['DataSource']['SslProperties']
type_ds = describe_data_source['DataSource']['Type']

# %%
#________________________ Function to create data sources_______________________________________________________
def create_ds(client, account_id,Data_source_Id,data_source_name,DataSourceParameter,SslProperty):
    DS_creation = client.create_data_source(
    AwsAccountId=account_id,
    DataSourceId=Data_source_Id,      #Ds_id, #we'll provide the ds id
    Name=data_source_name, #display name for the data source
    Type='ATHENA',
    DataSourceParameters=DataSourceParameter,
#     Credentials=Credential,
#     Permissions=[
#         {
#             'Principal': arn,
#             'Actions': [ "athena:*", "quicksight:*", "quicksight:CreateDataSource"]
#         },
#     ],
#     VpcConnectionProperties={
#         'VpcConnectionArn': 'string'
#     },
    SslProperties=SslProperty)
    return DS_creation

# %%
# _____________________________________List dataset _______________________________________________________________
list_dataset = quicksight.list_data_sets(AwsAccountId=account_id)

list_dataset
# Out:
# {'ResponseMetadata': {'RequestId': 'cf7e169f-f1d6-418d-ab25-81786b9143de',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:49 GMT',
#    'content-type': 'application/json',
#    'content-length': '12482',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'cf7e169f-f1d6-418d-ab25-81786b9143de'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'DataSetSummaries': [{'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/03c1a407-8e03-49cf-b740-65e99febe0a9',
#    'DataSetId': '03c1a407-8e03-49cf-b740-65e99febe0a9',
#    'Name': 'scoringtable',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 13, 35, 37, 779000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 13, 35, 37, 779000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/0f8cb37d-f715-44d4-8be4-1a144d6e238f',
#    'DataSetId': '0f8cb37d-f715-44d4-8be4-1a144d6e238f',
#    'Name': 'brand_lkp',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 40, 54, 71000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 40, 54, 71000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/2f6d9159-252a-44aa-944b-b2942da1e769',
#    'DataSetId': '2f6d9159-252a-44aa-944b-b2942da1e769',
#    'Name': 'datadrifttbl',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 4, 9, 32, 543000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 4, 19, 15, 934000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/31b9ae04-94c6-41b6-b440-af671ef46c58',
#    'DataSetId': '31b9ae04-94c6-41b6-b440-af671ef46c58',
#    'Name': 'brand_lkp',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 32, 59, 476000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 32, 59, 476000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/37936363-0bcd-47c0-a0b0-7913d30f03ad',
#    'DataSetId': '37936363-0bcd-47c0-a0b0-7913d30f03ad',
#    'Name': 'Web and Social Media Analytics',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 268000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 57, 58000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/3d3a624f-0142-4d88-af15-0ddcd79060f0',
#    'DataSetId': '3d3a624f-0142-4d88-af15-0ddcd79060f0',
#    'Name': 'New custom SQL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 25, 34, 847000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 25, 42, 855000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/408cd8e3-1d57-49e7-9008-a4a6e164ded5',
#    'DataSetId': '408cd8e3-1d57-49e7-9008-a4a6e164ded5',
#    'Name': 'Business Review',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 463000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 18, 967000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/54fb1fd7-9984-4400-a692-27e761375505',
#    'DataSetId': '54fb1fd7-9984-4400-a692-27e761375505',
#    'Name': 'datadrift',
#    'CreatedTime': datetime.datetime(2022, 5, 26, 14, 58, 43, 80000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 12, 47, 63000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/5c1ee887-68bb-45b6-9fcd-3316e132f8c8',
#    'DataSetId': '5c1ee887-68bb-45b6-9fcd-3316e132f8c8',
#    'Name': 'Web and Social Media Analytics',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 987000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 19, 481000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/62702eb0-5649-4d16-be3d-6b10e08de73a',
#    'DataSetId': '62702eb0-5649-4d16-be3d-6b10e08de73a',
#    'Name': 'People Overview',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 55, 489000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 6, 11, 825000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/73ea6e3b-2758-4fb2-9be5-1369ab43ab85',
#    'DataSetId': '73ea6e3b-2758-4fb2-9be5-1369ab43ab85',
#    'Name': 'People Overview',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 0, 560000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 15, 859000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/859e85bd-e5c3-4b3b-bd7a-17523504b96f',
#    'DataSetId': '859e85bd-e5c3-4b3b-bd7a-17523504b96f',
#    'Name': 'ScoringTable',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 50, 38, 792000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 50, 59, 497000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/920994aa-c6c6-427b-a247-7d91d01e5677',
#    'DataSetId': '920994aa-c6c6-427b-a247-7d91d01e5677',
#    'Name': 'Sales Pipeline',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 44, 825000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 20, 0, 458000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/9cf884ef-69af-4e64-9644-f8cfedfeea82',
#    'DataSetId': '9cf884ef-69af-4e64-9644-f8cfedfeea82',
#    'Name': 'People Overview',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 44, 700000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 20, 0, 993000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/9d29af3f-3928-4ad0-b2d7-3c4410764305',
#    'DataSetId': '9d29af3f-3928-4ad0-b2d7-3c4410764305',
#    'Name': 'People Overview',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 311000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 57, 393000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/9e7c0337-f02e-48db-bd4f-0eaed5770914',
#    'DataSetId': '9e7c0337-f02e-48db-bd4f-0eaed5770914',
#    'Name': 'Business Review',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 55, 571000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 6, 10, 926000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/af625da2-07c0-4c25-a535-8c28ee6a542b',
#    'DataSetId': 'af625da2-07c0-4c25-a535-8c28ee6a542b',
#    'Name': 'Business Review',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 0, 704000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 16, 425000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/f1157d56-d6bb-48cc-8008-cc72d1sfc3cf',
#    'DataSetId': 'f1157d56-d6bb-48cc-8008-cc72d1sfc3cf',
#    'Name': 'Drift_Dataset_MLOPs',
#    'CreatedTime': datetime.datetime(2022, 6, 3, 1, 40, 42, 346000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 3, 1, 40, 42, 346000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/f1157d56-d6bb-48cc-8908-cc72d1sfc3cf',
#    'DataSetId': 'f1157d56-d6bb-48cc-8908-cc72d1sfc3cf',
#    'Name': 'Scoring_Dataset_MLOPs',
#    'CreatedTime': datetime.datetime(2022, 6, 2, 15, 14, 43, 771000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 2, 15, 14, 59, 949000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/b86a8b76-ce91-4fee-a660-4d4238b6d38f',
#    'DataSetId': 'b86a8b76-ce91-4fee-a660-4d4238b6d38f',
#    'Name': 'glue.csv',
#    'CreatedTime': datetime.datetime(2022, 3, 23, 1, 35, 54, 183000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 23, 1, 36, 9, 653000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/b8f64549-6a16-4de6-9094-900b5851e876',
#    'DataSetId': 'b8f64549-6a16-4de6-9094-900b5851e876',
#    'Name': 'Business Review',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 44, 434000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 59, 550000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/c67e5281-b3d9-4356-9b2f-5b226338189a',
#    'DataSetId': 'c67e5281-b3d9-4356-9b2f-5b226338189a',
#    'Name': 'People Overview',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 512000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 19, 188000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/c70bb31e-addf-4545-adb4-84d54f641b11',
#    'DataSetId': 'c70bb31e-addf-4545-adb4-84d54f641b11',
#    'Name': 'Web and Social Media Analytics',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 21000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 20, 0, 462000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/c7201876-886b-43d6-9ce9-6be48b0fc2c7',
#    'DataSetId': 'c7201876-886b-43d6-9ce9-6be48b0fc2c7',
#    'Name': 'Sales Pipeline',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 299000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 57, 190000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/d09c381f-b55a-42ba-929c-1808a74b81f3',
#    'DataSetId': 'd09c381f-b55a-42ba-929c-1808a74b81f3',
#    'Name': 'Web and Social Media Analytics',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 55, 673000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 6, 10, 833000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/d283c312-7099-43a1-a3a8-ba7416a3e15d',
#    'DataSetId': 'd283c312-7099-43a1-a3a8-ba7416a3e15d',
#    'Name': 'Sales Pipeline',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 270000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 18, 149000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/daa611ad-bd42-4e19-9f5e-707078bd65ec',
#    'DataSetId': 'daa611ad-bd42-4e19-9f5e-707078bd65ec',
#    'Name': 'Sales Pipeline',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 55, 560000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 6, 10, 757000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/daf2642c-1bbe-44a5-ba8e-f5ecfe77322f',
#    'DataSetId': 'daf2642c-1bbe-44a5-ba8e-f5ecfe77322f',
#    'Name': 'Scoring',
#    'CreatedTime': datetime.datetime(2022, 5, 31, 2, 52, 56, 856000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 11, 55, 467000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/de771c06-8534-4680-aef0-5f37584aee0d',
#    'DataSetId': 'de771c06-8534-4680-aef0-5f37584aee0d',
#    'Name': 'Web and Social Media Analytics',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 0, 936000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 16, 645000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/f5ba1fa2-7c2e-4a67-a9bf-017de2188dbc',
#    'DataSetId': 'f5ba1fa2-7c2e-4a67-a9bf-017de2188dbc',
#    'Name': 'Business Review',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 144000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 56, 547000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/fa09d4db-0ca6-4762-ace3-c97efea1ed07',
#    'DataSetId': 'fa09d4db-0ca6-4762-ace3-c97efea1ed07',
#    'Name': 'brand_lkp',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 26, 39, 831000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 26, 39, 831000, tzinfo=tzlocal()),
#    'ImportMode': 'DIRECT_QUERY',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/ffa31795-e2d7-48a7-bf9e-903aa4649813',
#    'DataSetId': 'ffa31795-e2d7-48a7-bf9e-903aa4649813',
#    'Name': 'Sales Pipeline',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 0, 531000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 16, 323000, tzinfo=tzlocal()),
#    'ImportMode': 'SPICE',
#    'RowLevelPermissionTagConfigurationApplied': False,
#    'ColumnLevelPermissionRulesApplied': False}],
#  'RequestId': 'cf7e169f-f1d6-418d-ab25-81786b9143de'}

# %%
for i in list_dataset['DataSetSummaries']:
    if i ['Name'] == 'Scoring_Dataset_MLOPs':
        print(i)
# Out:
# {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/f1157d56-d6bb-48cc-8908-cc72d1sfc3cf', 'DataSetId': 'f1157d56-d6bb-48cc-8908-cc72d1sfc3cf', 'Name': 'Scoring_Dataset_MLOPs', 'CreatedTime': datetime.datetime(2022, 6, 2, 15, 14, 43, 771000, tzinfo=tzlocal()), 'LastUpdatedTime': datetime.datetime(2022, 6, 2, 15, 14, 59, 949000, tzinfo=tzlocal()), 'ImportMode': 'SPICE', 'RowLevelPermissionTagConfigurationApplied': False, 'ColumnLevelPermissionRulesApplied': False}

# %%
DataSetId = 'daf2642c-1bbe-44a5-ba8e-f5ecfe77322f'

# _________________________________Describe dataset ________________________________________________________________
describe_dataset = client.describe_data_set(AwsAccountId=account_id, DataSetId= DataSetId)

describe_dataset
# Out:
# {'ResponseMetadata': {'RequestId': 'd1c81937-0923-4039-90a1-32ffb4c88f51',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:51 GMT',
#    'content-type': 'application/json',
#    'content-length': '7391',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'd1c81937-0923-4039-90a1-32ffb4c88f51'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'DataSet': {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:dataset/daf2642c-1bbe-44a5-ba8e-f5ecfe77322f',
#   'DataSetId': 'daf2642c-1bbe-44a5-ba8e-f5ecfe77322f',
#   'Name': 'Scoring',
#   'CreatedTime': datetime.datetime(2022, 5, 31, 2, 52, 56, 856000, tzinfo=tzlocal()),
#   'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 11, 55, 467000, tzinfo=tzlocal()),
#   'PhysicalTableMap': {'b63ff894-b0be-4f23-83c4-e395f1f4066c': {'CustomSql': {'DataSourceArn': 'arn:aws:quicksight:us-east-1:854807003520:datasource/4847c388-271b-4e16-84ee-176cac01c4bb',
#      'Name': 'Scoring',
#      'SqlQuery': 'select scr.*,\n\nbsline.* from \n\n(SELECT case when modelname in (\'XGBoost\',\'XGboost\') then \'XGboost\'\n\nwhen modelname in (\'Linear Learner\',\'LinearLearner\') then \'Linear Learner\'\n\nend vmodelname,* FROM "modelmonitordb"."scoringtable" \n\nwhere infertype in(\'realtime\',\'Batch\'))scr,\n\n(select modelname bslinemodelname,valtype, kv[\'year\'] as "bslineyear",\n\nkv[\'odometer\'] as "bslineodometer",\n\nkv[\'price\'] as "bslineprice",\n\nkv[\'cylinders\'] as "bslinecylinders",\n\nkv[\'drive\'] as "bslinedrive",\n\nkv[\'type\'] as "bslinetype",\n\nkv[\'title_status\'] as "bslinetitle_status",\n\nkv[\'transmission\'] as "bslinetransmission"\n\nfrom\n\n(SELECT \'XGboost\' as modelname,\'meanval\' as valtype,map_agg(feature,meanval) kv\n\nFROM  "modelmonitordb"."baselineref"\n\nunion\n\nSELECT \'Linear Learner\' as modelname,\'meanval\' as valtype,map_agg(feature,meanval) kv\n\nFROM  "modelmonitordb"."baselineref")\n\n)bsline\n\nwhere scr.vmodelname=bsline.bslinemodelname',
#      'Columns': [{'Name': 'vmodelname', 'Type': 'STRING'},
#       {'Name': 'runtime', 'Type': 'STRING'},
#       {'Name': 'modelname', 'Type': 'STRING'},
#       {'Name': 'infertype', 'Type': 'STRING'},
#       {'Name': 'inferenceid', 'Type': 'STRING'},
#       {'Name': 'year', 'Type': 'STRING'},
#       {'Name': 'manufacturer', 'Type': 'STRING'},
#       {'Name': 'model', 'Type': 'STRING'},
#       {'Name': 'condition', 'Type': 'STRING'},
#       {'Name': 'cylinders', 'Type': 'STRING'},
#       {'Name': 'fuel', 'Type': 'STRING'},
#       {'Name': 'odometer', 'Type': 'STRING'},
#       {'Name': 'titlestatus', 'Type': 'STRING'},
#       {'Name': 'transmission', 'Type': 'STRING'},
#       {'Name': 'drive', 'Type': 'STRING'},
#       {'Name': 'type', 'Type': 'STRING'},
#       {'Name': 'paintcolor', 'Type': 'STRING'},
#       {'Name': 'predprice', 'Type': 'STRING'},
#       {'Name': 'bslinemodelname', 'Type': 'STRING'},
#       {'Name': 'valtype', 'Type': 'STRING'},
#       {'Name': 'bslineyear', 'Type': 'STRING'},
#       {'Name': 'bslineodometer', 'Type': 'STRING'},
#       {'Name': 'bslineprice', 'Type': 'STRING'},
#       {'Name': 'bslinecylinders', 'Type': 'STRING'},
#       {'Name': 'bslinedrive', 'Type': 'STRING'},
#       {'Name': 'bslinetype', 'Type': 'STRING'},
#       {'Name': 'bslinetitle_status', 'Type': 'STRING'},
#       {'Name': 'bslinetransmission', 'Type': 'STRING'}]}}},
#   'LogicalTableMap': {'b63ff894-b0be-4f23-83c4-e395f1f4066c': {'Alias': 'Scoring',
#     'DataTransforms': [{'CastColumnTypeOperation': {'ColumnName': 'runtime',
#        'NewColumnType': 'DATETIME',
#        'Format': 'yyyy-MM-dd HH:mm:ss'}},
#      {'CastColumnTypeOperation': {'ColumnName': 'odometer',
#        'NewColumnType': 'DECIMAL'}},
#      {'CastColumnTypeOperation': {'ColumnName': 'predprice',
#        'NewColumnType': 'DECIMAL'}},
#      {'CastColumnTypeOperation': {'ColumnName': 'bslineodometer',
#        'NewColumnType': 'DECIMAL'}},
#      {'CastColumnTypeOperation': {'ColumnName': 'bslineprice',
#        'NewColumnType': 'DECIMAL'}},
#      {'CreateColumnsOperation': {'Columns': [{'ColumnName': 'RunDay',
#          'ColumnId': '0299552c-fe62-4edf-b171-be5b890b921b',
#          'Expression': "extract('DD',{runtime})"}]}},
#      {'CreateColumnsOperation': {'Columns': [{'ColumnName': 'RunHour',
#          'ColumnId': '34a421db-86ea-4994-af4d-7df876bf4a24',
#          'Expression': "extract('HH',{runtime})"}]}},
#      {'ProjectOperation': {'ProjectedColumns': ['vmodelname',
#         'runtime',
#         'modelname',
#         'infertype',
#         'inferenceid',
#         'year',
#         'manufacturer',
#         'model',
#         'condition',
#         'cylinders',
#         'fuel',
#         'odometer',
#         'titlestatus',
#         'transmission',
#         'drive',
#         'type',
#         'paintcolor',
#         'predprice',
#         'bslinemodelname',
#         'valtype',
#         'bslineyear',
#         'bslineodometer',
#         'bslineprice',
#         'bslinecylinders',
#         'bslinedrive',
#         'bslinetype',
#         'bslinetitle_status',
#         'bslinetransmission',
#         'RunDay',
#         'RunHour']}}],
#     'Source': {'PhysicalTableId': 'b63ff894-b0be-4f23-83c4-e395f1f4066c'}}},
#   'OutputColumns': [{'Name': 'vmodelname', 'Type': 'STRING'},
#    {'Name': 'runtime', 'Type': 'DATETIME'},
#    {'Name': 'modelname', 'Type': 'STRING'},
#    {'Name': 'infertype', 'Type': 'STRING'},
#    {'Name': 'inferenceid', 'Type': 'STRING'},
#    {'Name': 'year', 'Type': 'STRING'},
#    {'Name': 'manufacturer', 'Type': 'STRING'},
#    {'Name': 'model', 'Type': 'STRING'},
#    {'Name': 'condition', 'Type': 'STRING'},
#    {'Name': 'cylinders', 'Type': 'STRING'},
#    {'Name': 'fuel', 'Type': 'STRING'},
#    {'Name': 'odometer', 'Type': 'DECIMAL'},
#    {'Name': 'titlestatus', 'Type': 'STRING'},
#    {'Name': 'transmission', 'Type': 'STRING'},
#    {'Name': 'drive', 'Type': 'STRING'},
#    {'Name': 'type', 'Type': 'STRING'},
#    {'Name': 'paintcolor', 'Type': 'STRING'},
#    {'Name': 'predprice', 'Type': 'DECIMAL'},
#    {'Name': 'bslinemodelname', 'Type': 'STRING'},
#    {'Name': 'valtype', 'Type': 'STRING'},
#    {'Name': 'bslineyear', 'Type': 'STRING'},
#    {'Name': 'bslineodometer', 'Type': 'DECIMAL'},
#    {'Name': 'bslineprice', 'Type': 'DECIMAL'},
#    {'Name': 'bslinecylinders', 'Type': 'STRING'},
#    {'Name': 'bslinedrive', 'Type': 'STRING'},
#    {'Name': 'bslinetype', 'Type': 'STRING'},
#    {'Name': 'bslinetitle_status', 'Type': 'STRING'},
#    {'Name': 'bslinetransmission', 'Type': 'STRING'},
#    {'Name': 'RunDay', 'Type': 'INTEGER'},
#    {'Name': 'RunHour', 'Type': 'INTEGER'}],
#   'ImportMode': 'SPICE',
#   'ConsumedSpiceCapacityInBytes': 20045804,
#   'ColumnGroups': [],
#   'FieldFolders': {},
#   'DataSetUsageConfiguration': {'DisableUseAsDirectQuerySource': False,
#    'DisableUseAsImportedSource': False}},
#  'RequestId': 'd1c81937-0923-4039-90a1-32ffb4c88f51'}

# %%
with open ("scoring_data_set.json", "w") as outfile:
    json.dump(describe_dataset, outfile, indent=4, sort_keys=True, default=str) # dictionary to json

# %% [markdown]
# # ---------------------------- List analysis ---------------------------------

# %%
list_analysis = client.list_analyses(AwsAccountId=account_id)
list_analysis
# Out:
# {'ResponseMetadata': {'RequestId': 'c3724088-091f-4c79-9581-41a703b9555a',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:53 GMT',
#    'content-type': 'application/json',
#    'content-length': '9918',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'c3724088-091f-4c79-9581-41a703b9555a'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'AnalysisSummaryList': [{'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/087a00f6-39f5-4190-a807-13591e97070a',
#    'AnalysisId': '087a00f6-39f5-4190-a807-13591e97070a',
#    'Name': 'Business Review analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 94000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 94000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/16255761-f6bb-4b46-9f79-5ab75b68da11',
#    'AnalysisId': '16255761-f6bb-4b46-9f79-5ab75b68da11',
#    'Name': 'Web and Social Media Analytics analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 583000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 583000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/172b6dcc-b9cf-43d2-879e-341c92a61b49',
#    'AnalysisId': '172b6dcc-b9cf-43d2-879e-341c92a61b49',
#    'Name': 'brand_lkp analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 26, 40, 63000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 26, 47, 529000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/1a4928e6-c76f-4bfb-9988-7c803f3d425b',
#    'AnalysisId': '1a4928e6-c76f-4bfb-9988-7c803f3d425b',
#    'Name': 'Sales Pipeline analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 257000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 257000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/1ac9cf68-a2e1-4020-995c-52c9a3c1cc36',
#    'AnalysisId': '1ac9cf68-a2e1-4020-995c-52c9a3c1cc36',
#    'Name': 'Sales Pipeline analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 437000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 437000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/275f9ec2-f0ca-49eb-96f6-37a5de60e8cb',
#    'AnalysisId': '275f9ec2-f0ca-49eb-96f6-37a5de60e8cb',
#    'Name': 'glue.csv analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 23, 1, 36, 48, 72000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 5, 15, 48, 171000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/32241aa6-7ccc-41e2-a7fb-995e3bd6adf1',
#    'AnalysisId': '32241aa6-7ccc-41e2-a7fb-995e3bd6adf1',
#    'Name': 'People Overview analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 903000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 903000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/388c3fbb-28e6-4cea-83ad-78e7f7d06526',
#    'AnalysisId': '388c3fbb-28e6-4cea-83ad-78e7f7d06526',
#    'Name': 'mlops_datadrift_viz_May27',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 3, 30, 25, 711000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 3, 48, 6, 984000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/53d7bbba-1e10-4471-9044-296b26bc80b8',
#    'AnalysisId': '53d7bbba-1e10-4471-9044-296b26bc80b8',
#    'Name': 'Sales Pipeline analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 185000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 185000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/5aeb6958-4e0c-4fe0-b720-a4d9750612f9',
#    'AnalysisId': '5aeb6958-4e0c-4fe0-b720-a4d9750612f9',
#    'Name': 'datadrift analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 26, 14, 58, 52, 74000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 3, 1, 27, 235000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/605da1af-61ae-4555-8689-f4fe74cb2f25',
#    'AnalysisId': '605da1af-61ae-4555-8689-f4fe74cb2f25',
#    'Name': 'People Overview analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 388000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 388000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/6378cf46-08a0-487a-8fcf-18070ff7b9ca',
#    'AnalysisId': '6378cf46-08a0-487a-8fcf-18070ff7b9ca',
#    'Name': 'Sales Pipeline analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 920000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 3, 920000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/6a48423f-2adc-411f-8a6d-739d8b28284a',
#    'AnalysisId': '6a48423f-2adc-411f-8a6d-739d8b28284a',
#    'Name': 'Web and Social Media Analytics analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 288000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 288000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/6ac278dc-1a23-4918-a331-262245b39183',
#    'AnalysisId': '6ac278dc-1a23-4918-a331-262245b39183',
#    'Name': 'brand_lkp analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 23, 16, 40, 54, 320000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 23, 16, 40, 54, 320000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/6f2e0df1-e22f-4702-9ed7-edebb2ddde8f',
#    'AnalysisId': '6f2e0df1-e22f-4702-9ed7-edebb2ddde8f',
#    'Name': 'Business Review analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 180000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 180000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/7be6f21e-0459-4f3d-b119-a71d7b6d7304',
#    'AnalysisId': '7be6f21e-0459-4f3d-b119-a71d7b6d7304',
#    'Name': 'scoringtable analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 13, 35, 38, 48000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 13, 35, 38, 48000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/7d4b427d-5f42-4eb2-a4b6-a38a07ebf45b',
#    'AnalysisId': '7d4b427d-5f42-4eb2-a4b6-a38a07ebf45b',
#    'Name': 'Business Review analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 105000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 105000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/8b0c1ee9-ab17-4973-83c8-15cfbd446f64',
#    'AnalysisId': '8b0c1ee9-ab17-4973-83c8-15cfbd446f64',
#    'Name': 'Drift_analysis_May26',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 3, 48, 45, 305000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 34, 17, 423000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/942ab365-84aa-435e-a0f0-ce886c91d031',
#    'AnalysisId': '942ab365-84aa-435e-a0f0-ce886c91d031',
#    'Name': 'Business Review analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 475000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 475000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/97887815-1dfb-40c8-b4f9-5864dd0a8a1c',
#    'AnalysisId': '97887815-1dfb-40c8-b4f9-5864dd0a8a1c',
#    'Name': 'New custom SQL analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 5, 25, 35, 927000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 5, 25, 35, 927000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/9aa3a687-05f7-48b1-b245-ff45ef0185c1',
#    'AnalysisId': '9aa3a687-05f7-48b1-b245-ff45ef0185c1',
#    'Name': 'People Overview analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 332000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 18, 14, 38, 1, 332000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/9f27b9fa-47e1-4b33-822a-3a1e6c22fe6b',
#    'AnalysisId': '9f27b9fa-47e1-4b33-822a-3a1e6c22fe6b',
#    'Name': 'glue.csv analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 23, 1, 35, 54, 923000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 23, 1, 35, 54, 923000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a3993225-ea28-46d9-91e3-76678fa97cb2',
#    'AnalysisId': 'a3993225-ea28-46d9-91e3-76678fa97cb2',
#    'Name': 'data drift analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 22, 21, 38, 44, 231000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 22, 21, 39, 12, 425000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a3e2376b-4ffd-41c7-87ac-eecc62ef1545',
#    'AnalysisId': 'a3e2376b-4ffd-41c7-87ac-eecc62ef1545',
#    'Name': 'Scoring Analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 31, 2, 52, 57, 110000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 10, 32, 890000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a6493e46-7375-4f23-806f-12a07dd4dda7',
#    'AnalysisId': 'a6493e46-7375-4f23-806f-12a07dd4dda7',
#    'Name': 'Datadrift_visualization_mlops',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 27, 3, 2, 31, 905000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 27, 3, 29, 24, 430000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a6d1e7ec-78f3-48fb-acf9-45aa64ee3fa3',
#    'AnalysisId': 'a6d1e7ec-78f3-48fb-acf9-45aa64ee3fa3',
#    'Name': 'People Overview analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 145000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 145000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a91f9298-4309-4cc8-a14d-b546ddd828ee',
#    'AnalysisId': 'a91f9298-4309-4cc8-a14d-b546ddd828ee',
#    'Name': 'datadrifttbl analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 24, 4, 19, 16, 311000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 24, 7, 18, 14, 929000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/aef525b4-ca19-49a7-99da-9a29b9f6a5aa',
#    'AnalysisId': 'aef525b4-ca19-49a7-99da-9a29b9f6a5aa',
#    'Name': 'People Overview analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 175000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 4, 18, 5, 56, 175000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/cf319b05-24c3-4156-b48b-404d28d8ae51',
#    'AnalysisId': 'cf319b05-24c3-4156-b48b-404d28d8ae51',
#    'Name': 'Business Review analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 868000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 868000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/cf8efc79-6c81-45af-8c5a-56575f73bec1',
#    'AnalysisId': 'cf8efc79-6c81-45af-8c5a-56575f73bec1',
#    'Name': 'Web and Social Media Analytics analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 707000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 1, 19, 19, 45, 707000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/e2dfa071-96ee-4856-bf54-1795849cd740',
#    'AnalysisId': 'e2dfa071-96ee-4856-bf54-1795849cd740',
#    'Name': 'Sales Pipeline analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 992000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 992000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/e31ef22c-5de5-44a0-8ccc-b8180b1a778a',
#    'AnalysisId': 'e31ef22c-5de5-44a0-8ccc-b8180b1a778a',
#    'Name': 'Test_MLops',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 23, 1, 36, 26, 956000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 19, 1, 27, 34, 117000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/f20fd653-ce19-4922-bba0-eb1da4fbeeaf',
#    'AnalysisId': 'f20fd653-ce19-4922-bba0-eb1da4fbeeaf',
#    'Name': 'Web and Social Media Analytics analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 764000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 3, 17, 19, 7, 4, 764000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/f59ec023-0ccc-4a0b-8cd7-074ed0131981',
#    'AnalysisId': 'f59ec023-0ccc-4a0b-8cd7-074ed0131981',
#    'Name': 'Web and Social Media Analytics analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 899000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 7, 41, 899000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/ffe844fa-e8ea-4131-9173-7781302b1584',
#    'AnalysisId': 'ffe844fa-e8ea-4131-9173-7781302b1584',
#    'Name': 'brand_lkp analysis',
#    'Status': 'CREATION_SUCCESSFUL',
#    'CreatedTime': datetime.datetime(2022, 5, 11, 21, 32, 59, 740000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 5, 11, 21, 33, 50, 295000, tzinfo=tzlocal())}],
#  'RequestId': 'c3724088-091f-4c79-9581-41a703b9555a'}

# %%
analysis_id = 'a3e2376b-4ffd-41c7-87ac-eecc62ef1545'

### --------------------- Desribe analysis -------------------------------------------------------
describe_analysis = client.describe_analysis(AwsAccountId=account_id, AnalysisId=analysis_id)
describe_analysis
# Out:
# {'ResponseMetadata': {'RequestId': 'c2d5ce2d-bade-44e4-a259-5686527a2728',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:41:53 GMT',
#    'content-type': 'application/json',
#    'content-length': '1358',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': 'c2d5ce2d-bade-44e4-a259-5686527a2728'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'Analysis': {'AnalysisId': 'a3e2376b-4ffd-41c7-87ac-eecc62ef1545',
#   'Arn': 'arn:aws:quicksight:us-east-1:854807003520:analysis/a3e2376b-4ffd-41c7-87ac-eecc62ef1545',
#   'Name': 'Scoring Analysis',
#   'Status': 'CREATION_SUCCESSFUL',
#   'DataSetArns': ['arn:aws:quicksight:us-east-1:854807003520:dataset/daf2642c-1bbe-44a5-ba8e-f5ecfe77322f'],
#   'ThemeArn': 'arn:aws:quicksight::aws:theme/MIDNIGHT',
#   'CreatedTime': datetime.datetime(2022, 5, 31, 2, 52, 57, 110000, tzinfo=tzlocal()),
#   'LastUpdatedTime': datetime.datetime(2022, 6, 1, 18, 10, 32, 890000, tzinfo=tzlocal()),
#   'Sheets': [{'SheetId': 'fb9e7414-cb6f-44e6-9e0d-c95c128937eb',
#     'Name': 'priceTrendPred'},
#    {'SheetId': '915baec4-50c6-44c0-a797-0a5be9a39161',
#     'Name': 'PredPriceTable'},
#    {'SheetId': 'baf27702-a6c4-4438-a448-c4425402c863', 'Name': 'Sheet 3'}]},
#  'RequestId': 'c2d5ce2d-bade-44e4-a259-5686527a2728'}

# %%
analysis_id = describe_analysis['Analysis']['AnalysisId']

arn = describe_analysis['Analysis']['Arn']

dataset_arn = describe_analysis['Analysis']['DataSetArns'][0]

# %% [markdown]
# # Creating the data Source

# %%
#________________________ Function to create data sources_______________________________________________________
def create_ds(client, account_id,Data_source_Id,data_source_name,DataSourceParameter,SslProperty,types):
    DS_creation = client.create_data_source(
    AwsAccountId=account_id,
    DataSourceId=Data_source_Id,      #Ds_id, #we'll provide the ds id
    Name=data_source_name, #display name for the data source
    Type=types,
    DataSourceParameters=DataSourceParameter,
#     Credentials=Credential,
#     Permissions=[
#         {
#             'Principal': arn,
#             'Actions': [ "athena:*", "quicksight:*", "quicksight:CreateDataSource"]
#         },
#     ],
#     VpcConnectionProperties={
#         'VpcConnectionArn': 'string'
#     },
    SslProperties=SslProperty)
    return DS_creation

# %%
ds_Name = "Scoring_MLOPs"
ds_Id = '24e6bcd0-932e-4a9a-8b9d-bdf43ac09935'
# ds_Id = describe_data_source['DataSource']['DataSourceId']
# ds_Name = describe_data_source['DataSource']['Name']
ds_parameters = describe_data_source['DataSource']['DataSourceParameters']
ssl = describe_data_source['DataSource']['SslProperties']
type_ds = describe_data_source['DataSource']['Type']

# %%
create_ds(client, account_id, ds_Id, ds_Name, ds_parameters, ssl, type_ds)
# Out:
# ---------------------------------------------------------------------------
# ResourceExistsException                   Traceback (most recent call last)
# <ipython-input-73-1462573e136b> in <module>
# ----> 1 create_ds(client, account_id, ds_Id, ds_Name, ds_parameters, ssl, type_ds)
#
# <ipython-input-71-37737b1d23eb> in create_ds(client, account_id, Data_source_Id, data_source_name, DataSourceParameter, SslProperty, types)
#      17 #         'VpcConnectionArn': 'string'
#      18 #     },
# ---> 19     SslProperties=SslProperty)
#      20     return DS_creation
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     413                     "%s() only accepts keyword arguments." % py_operation_name)
#     414             # The "self" in this scope is referring to the BaseClient.
# --> 415             return self._make_api_call(operation_name, kwargs)
#     416
#     417         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     743             error_code = parsed_response.get("Error", {}).get("Code")
#     744             error_class = self.exceptions.from_code(error_code)
# --> 745             raise error_class(parsed_response, operation_name)
#     746         else:
#     747             return parsed_response
#
# ResourceExistsException: An error occurred (ResourceExistsException) when calling the CreateDataSource operation: DataSource datasource/24e6bcd0-932e-4a9a-8b9d-bdf43ac09935 already exists

# %% [markdown]
# # Creating Dataset

# %%
#_____________________________ Variables from the desribe dataset __________________________________________________
Import_Mode = describe_dataset['DataSet']['ImportMode']
Logical_TableMap=describe_dataset['DataSet']['LogicalTableMap']
Physical_TableMap=describe_dataset['DataSet']['PhysicalTableMap']
DataSet_Usage_Configuration = describe_dataset['DataSet']['DataSetUsageConfiguration']
dataset_Id = 'f1157d56-d6bb-48cc-8908-cc72d1sfc3cf'
dataset_Name = 'Scoring_Dataset_MLOPs'

#creating dataset

def create_dataset(client, account_id, dataset_id,dataset_name,Physical_TableMap,Logical_TableMap,Import_Mode,DataSet_Usage_Configuration ):
    output = client.create_data_set(
    AwsAccountId=account_id,
    DataSetId=dataset_id,
    Name=dataset_name, #dataset_name,
    PhysicalTableMap=Physical_TableMap,
    LogicalTableMap=Logical_TableMap,
    ImportMode=Import_Mode,    
    DataSetUsageConfiguration=DataSet_Usage_Configuration )
    return output

# %%
create_dataset(client, 
               account_id, 
               dataset_Id,
               dataset_Name,
               Physical_TableMap,
               Logical_TableMap,
               Import_Mode,
               DataSet_Usage_Configuration )
# Out:
# ---------------------------------------------------------------------------
# ResourceExistsException                   Traceback (most recent call last)
# <ipython-input-75-e22639c9c89c> in <module>
#       6                Logical_TableMap,
#       7                Import_Mode,
# ----> 8                DataSet_Usage_Configuration )
#
# <ipython-input-74-913668abebf5> in create_dataset(client, account_id, dataset_id, dataset_name, Physical_TableMap, Logical_TableMap, Import_Mode, DataSet_Usage_Configuration)
#      17     LogicalTableMap=Logical_TableMap,
#      18     ImportMode=Import_Mode,
# ---> 19     DataSetUsageConfiguration=DataSet_Usage_Configuration )
#      20     return output
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     413                     "%s() only accepts keyword arguments." % py_operation_name)
#     414             # The "self" in this scope is referring to the BaseClient.
# --> 415             return self._make_api_call(operation_name, kwargs)
#     416
#     417         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     743             error_code = parsed_response.get("Error", {}).get("Code")
#     744             error_class = self.exceptions.from_code(error_code)
# --> 745             raise error_class(parsed_response, operation_name)
#     746         else:
#     747             return parsed_response
#
# ResourceExistsException: An error occurred (ResourceExistsException) when calling the CreateDataSet operation: DataSet f1157d56-d6bb-48cc-8908-cc72d1sfc3cf already exists

# %% [markdown]
# # Template Creation

# %%
# ------------------------ List template ------------------------------
list_template = client.list_templates(AwsAccountId=account_id)

list_template
# Out:
# {'ResponseMetadata': {'RequestId': '1a0e88c8-3230-47b4-b7c8-efd34505e9c0',
#   'HTTPStatusCode': 200,
#   'HTTPHeaders': {'date': 'Fri, 03 Jun 2022 01:42:11 GMT',
#    'content-type': 'application/json',
#    'content-length': '640',
#    'connection': 'keep-alive',
#    'x-amzn-requestid': '1a0e88c8-3230-47b4-b7c8-efd34505e9c0'},
#   'RetryAttempts': 0},
#  'Status': 200,
#  'TemplateSummaryList': [{'Arn': 'arn:aws:quicksight:us-east-1:854807003520:template/0696bc2d-b446-4de1-922c-1569b20ff97d',
#    'TemplateId': '0696bc2d-b446-4de1-922c-1569b20ff97d',
#    'Name': 'mlops_scoring_template',
#    'LatestVersionNumber': 1,
#    'CreatedTime': datetime.datetime(2022, 6, 2, 15, 31, 1, 193000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 2, 15, 31, 1, 193000, tzinfo=tzlocal())},
#   {'Arn': 'arn:aws:quicksight:us-east-1:854807003520:template/0696bc2d-b446-4de1-922c-1569b29ff97d',
#    'TemplateId': '0696bc2d-b446-4de1-922c-1569b29ff97d',
#    'Name': 'mlops_data_drift_template',
#    'LatestVersionNumber': 1,
#    'CreatedTime': datetime.datetime(2022, 6, 3, 1, 41, 33, 131000, tzinfo=tzlocal()),
#    'LastUpdatedTime': datetime.datetime(2022, 6, 3, 1, 41, 33, 131000, tzinfo=tzlocal())}],
#  'RequestId': '1a0e88c8-3230-47b4-b7c8-efd34505e9c0'}

# %%
#-------------------------------- Creating template from analysis in DEV environment -------------------------

def creating_template_from_analysis(account_id, Template_Id, template_name, analysis_arn, dataset_placeholder, dataset_arn ):
    response = client.create_template(
    AwsAccountId=account_id,
    TemplateId=Template_Id,
    Name=template_name,
    SourceEntity={
        'SourceAnalysis': {
            'Arn': analysis_arn,
            'DataSetReferences': [
                {
                    'DataSetPlaceholder': dataset_placeholder,  #name for data
                    'DataSetArn': dataset_arn
                },
            ]
        } })
    return response

# %%
analysis_id = describe_analysis['Analysis']['AnalysisId']

arn = describe_analysis['Analysis']['Arn']

dataset_arn = describe_analysis['Analysis']['DataSetArns'][0]

Template_Id = '0696bc2d-b446-4de1-922c-1569b20ff97d'

template_name = 'mlops_scoring_template'

dataset_placeholder = 'mlops_scoring_placeholder'

# %%
creating_template_from_analysis(account_id, 
                                Template_Id, 
                                template_name, 
                                arn, 
                                dataset_placeholder, 
                                dataset_arn )
# Out:
# ---------------------------------------------------------------------------
# ResourceExistsException                   Traceback (most recent call last)
# <ipython-input-79-496d1c703fc0> in <module>
#       4                                 arn,
#       5                                 dataset_placeholder,
# ----> 6                                 dataset_arn )
#
# <ipython-input-77-96a46bc4c7d4> in creating_template_from_analysis(account_id, Template_Id, template_name, analysis_arn, dataset_placeholder, dataset_arn)
#      12                 {
#      13                     'DataSetPlaceholder': dataset_placeholder,  #name for data
# ---> 14                     'DataSetArn': dataset_arn
#      15                 },
#      16             ]
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _api_call(self, *args, **kwargs)
#     413                     "%s() only accepts keyword arguments." % py_operation_name)
#     414             # The "self" in this scope is referring to the BaseClient.
# --> 415             return self._make_api_call(operation_name, kwargs)
#     416
#     417         _api_call.__name__ = str(py_operation_name)
#
# ~/anaconda3/envs/python3/lib/python3.6/site-packages/botocore/client.py in _make_api_call(self, operation_name, api_params)
#     743             error_code = parsed_response.get("Error", {}).get("Code")
#     744             error_class = self.exceptions.from_code(error_code)
# --> 745             raise error_class(parsed_response, operation_name)
#     746         else:
#     747             return parsed_response
#
# ResourceExistsException: An error occurred (ResourceExistsException) when calling the CreateTemplate operation: Template arn:aws:quicksight:us-east-1:854807003520:template/0696bc2d-b446-4de1-922c-1569b20ff97d already exists

# %%
#________________________ Function to create data sources_______________________________________________________
def create_ds(client, account_id,Data_source_Id,data_source_name,DataSourceParameter,SslProperty):
    DS_creation = client.create_data_source(
    AwsAccountId=account_id,
    DataSourceId=Data_source_Id,      #Ds_id, #we'll provide the ds id
    Name=data_source_name, #display name for the data source
    Type='ATHENA',
    DataSourceParameters=DataSourceParameter,
#     Credentials=Credential,
#     Permissions=[
#         {
#             'Principal': arn,
#             'Actions': [ "athena:*", "quicksight:*", "quicksight:CreateDataSource"]
#         },
#     ],
#     VpcConnectionProperties={
#         'VpcConnectionArn': 'string'
#     },
    SslProperties=SslProperty)
    return DS_creation

# _____________________________________List dataset _______________________________________________________________
list_dataset = quicksight.list_data_sets(AwsAccountId=account_id)


# _________________________________Describe dataset ________________________________________________________________
describe_dataset = client.describe_data_set(AwsAccountId=account_id, DataSetId= '05dbeb9e-6ce3-475e-bc58-6664e87992be')

#_____________________________ Variables from the desribe dataset __________________________________________________
Import_Mode = describe_dataset['DataSet']['ImportMode']
Logical_TableMap=describe_dataset['DataSet']['LogicalTableMap']
Physical_TableMap=describe_dataset['DataSet']['PhysicalTableMap']
DataSet_Usage_Configuration = describe_dataset['DataSet']['DataSetUsageConfiguration']
dataset_Id = describe_dataset['DataSet']['DataSetId']
dataset_Name = describe_dataset['DataSet']['Name']

#creating dataset

def create_dataset(client, account_id, dataset_id,dataset_name,Physical_TableMap,Logical_TableMap,Import_Mode,DataSet_Usage_Configuration ):
    output = client.create_data_set(
    AwsAccountId=account_id,
    DataSetId=dataset_id,
    Name=dataset_name, #dataset_name,
    PhysicalTableMap=Physical_TableMap,
    LogicalTableMap=Logical_TableMap,
    ImportMode=Import_Mode,    
    DataSetUsageConfiguration=DataSet_Usage_Configuration )
    return output


# ------------------------ List template ------------------------------
list_template = client.list_templates(AwsAccountId=account_id)

des_template = client.list_templates(AwsAccountId=account_id,TemplateId=templateID)

template_arn = des_template['Template']['Arn']


#-------------------------------- Creating template from analysis in DEV environment -------------------------

def creating_template_from_analysis(account_id, Template_Id, template_name, analysis_arn, dataset_placeholder, dataset_arn ):
    response = client.create_template(
    AwsAccountId=account_id,
    TemplateId=Template_Id,
    Name=template_name,
    SourceEntity={
        'SourceAnalysis': {
            'Arn': analysis_arn,
            'DataSetReferences': [
                {
                    'DataSetPlaceholder': dataset_placeholder,  #name for data
                    'DataSetArn': dataset_arn
                },
            ]
        } })
    return response

# -------------------------Creating template from template -------------------------------------------
def create_template_from_template(account_id,Template_Id,template_name,tempalte_arn):
    response = client.create_template(
    AwsAccountId=account_id,
    TemplateId=Template_Id,
    Name=template_name,
    SourceEntity={
        'SourceTemplate': {
            'Arn': tempalte_arn
        }
    })
    return response



# ---------------------------- List analysis ---------------------------------
list_analysis = client.list_analyses(AwsAccountId=account_id)

### --------------------- Desribe analysis -------------------------------------------------------
describe_analysis = client.describe_analysis(AwsAccountId=account_id, AnalysisId=analysis_id)

# ----------------------- variables from analysis description ----------------------------------------
analysis_id = describe_analysis['Analysis']['AnalysisId']
arn = describe_analysis['Analysis']['Arn']
dataset_arn = describe_analysis['Analysis']['DataSetArns'][0]


# --------------------   Creating analysis from template -----------------------------------------
def creating_analysis(client, account_id, analysis_id, analysis_name,dataset_placeholder,dataset_arn, template_arn):
    response = client.create_analysis(
    AwsAccountId=account_id,
    AnalysisId=analysis_id,
    Name=analysis_name,
    SourceEntity={
        'SourceTemplate': {
            'DataSetReferences': [
                {
                    'DataSetPlaceholder': dataset_placeholder,
                    'DataSetArn': dataset_arn
                },
            ],
            "Arn":template_arn,
                }
            }
        )
    return response


def creating_dashboard(client,account_id,dashboard_id,dashboard_name,Iam_arn,dataset_placeholder,dataset_arn,template_arn,):
    response = client.create_dashboard(
    AwsAccountId=account_id,
    DashboardId=dashboard_id, #The ID for the dashboard, also added to the IAM policy.
    Name=dashboard_name,
    Permissions=[
        {
            'Principal': Iam_arn,
            'Actions': [
                'quicksight:DescribeDashboard',
                'quicksight:ListDashboardVersions',
                'quicksight:UpdateDashboardPermissions',
                'quicksight:QueryDashboard',
                'quicksight:UpdateDashboard',
                'quicksight:DeleteDashboard',
                'quicksight:DescribeDashboardPermissions',
                'quicksight:UpdateDashboardPublishedVersion'
            ]
        },
    ],
    SourceEntity={
        'SourceTemplate': {
            'DataSetReferences': [
                {
                    'DataSetPlaceholder': dataset_placeholder,
                    'DataSetArn': dataset_arn
                },
            ],
            'Arn': template_arn
        }
    },
    VersionDescription='1.0',
    DashboardPublishOptions={
        'AdHocFilteringOption': {
            'AvailabilityStatus': 'ENABLED'|'DISABLED'
        },
        'ExportToCSVOption': {
            'AvailabilityStatus': 'ENABLED'|'DISABLED'
        },
        'SheetControlsOption': {
            'VisibilityState': 'EXPANDED'|'COLLAPSED'
        }
    })
    return response



    def updating_template(client, account_id,Template_id, template_arn,template_version, template_name):
        response = client.update_template(
        AwsAccountId=account_id,
        TemplateId=Template_id,
        SourceEntity={
            'SourceTemplate': {
                'Arn': template_arn
            }
        },
        VersionDescription=template_version,
        Name=template_name)
        return response
